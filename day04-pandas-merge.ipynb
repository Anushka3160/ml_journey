# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/meruvakodandasuraj/e-commerce-customer-behavior-and-sales-20202026/product_summary.csv
# /kaggle/input/datasets/meruvakodandasuraj/e-commerce-customer-behavior-and-sales-20202026/monthly_revenue.csv
# /kaggle/input/datasets/meruvakodandasuraj/e-commerce-customer-behavior-and-sales-20202026/orders.csv
# /kaggle/input/datasets/meruvakodandasuraj/e-commerce-customer-behavior-and-sales-20202026/customers.csv

# %%
df1=pd.read_csv("/kaggle/input/datasets/meruvakodandasuraj/e-commerce-customer-behavior-and-sales-20202026/customers.csv")
df2=pd.read_csv("/kaggle/input/datasets/meruvakodandasuraj/e-commerce-customer-behavior-and-sales-20202026/orders.csv")

# %%
df1
# Out:
#      customer_id        country  age  gender membership_tier  \
# 0         C00001  United States   40    Male            Free
# 1         C00002  United States   20  Female            Free
# 2         C00003  United States   43  Female            Gold
# 3         C00004  United States   41    Male            Free
# 4         C00005         France   37   Other        Platinum
# ...          ...            ...  ...     ...             ...
# 7995      C07996  United States   36    Male            Gold
# 7996      C07997          India   42    Male            Free
# 7997      C07998          India   34    Male        Platinum
# 7998      C07999          Japan   44  Female            Free
# 7999      C08000         Poland   37  Female            Gold
#
#      registration_date  total_orders  total_spend_usd  avg_order_value_usd  \
# 0           2019-01-17             4           286.63                63.78
# 1           2026-03-04            11          1245.18               107.32
# ...

# %%
df2
# Out:
#       order_id customer_id  order_date  year  month quarter day_of_week  \
# 0      O000001      C07108  2020-08-27  2020      8      Q3    Thursday
# 1      O000002      C03487  2024-04-11  2024      4      Q2    Thursday
# 2      O000003      C03062  2023-06-25  2023      6      Q2      Sunday
# 3      O000004      C00888  2020-08-16  2020      8      Q3      Sunday
# 4      O000005      C01674  2020-04-24  2020      4      Q2      Friday
# ...        ...         ...         ...   ...    ...     ...         ...
# 24995  O024996      C07416  2023-03-15  2023      3      Q1   Wednesday
# 24996  O024997      C04387  2024-04-22  2024      4      Q2      Monday
# 24997  O024998      C07566  2023-06-07  2023      6      Q2   Wednesday
# 24998  O024999      C04986  2024-05-06  2024      5      Q2      Monday
# 24999  O025000      C06995  2020-08-17  2020      8      Q3      Monday
#
#                product_name               category  unit_price_usd  ...  \
# ...

# %%
pd.merge(df1,df2, on="customer_id", how="inner")
# Out:
#       customer_id        country  age  gender membership_tier  \
# 0          C00001  United States   40    Male            Free
# 1          C00001  United States   40    Male            Free
# 2          C00002  United States   20  Female            Free
# 3          C00002  United States   20  Female            Free
# 4          C00002  United States   20  Female            Free
# ...           ...            ...  ...     ...             ...
# 24995      C07997          India   42    Male            Free
# 24996      C07998          India   34    Male        Platinum
# 24997      C07999          Japan   44  Female            Free
# 24998      C07999          Japan   44  Female            Free
# 24999      C07999          Japan   44  Female            Free
#
#       registration_date  total_orders  total_spend_usd  avg_order_value_usd  \
# 0            2019-01-17             4           286.63                63.78
# ...

# %%
pd.merge(df1,df2, on="customer_id", how="left")
# Out:
#       customer_id        country  age  gender membership_tier  \
# 0          C00001  United States   40    Male            Free
# 1          C00001  United States   40    Male            Free
# 2          C00002  United States   20  Female            Free
# 3          C00002  United States   20  Female            Free
# 4          C00002  United States   20  Female            Free
# ...           ...            ...  ...     ...             ...
# 25332      C07998          India   34    Male        Platinum
# 25333      C07999          Japan   44  Female            Free
# 25334      C07999          Japan   44  Female            Free
# 25335      C07999          Japan   44  Female            Free
# 25336      C08000         Poland   37  Female            Gold
#
#       registration_date  total_orders  total_spend_usd  avg_order_value_usd  \
# 0            2019-01-17             4           286.63                63.78
# ...

# %%
pd.merge(df1,df2, on="customer_id", how="right")
# Out:
#       customer_id         country  age  gender membership_tier  \
# 0          C07108   United States   30  Female            Free
# 1          C03487         Germany   39    Male            Gold
# 2          C03062           Italy   39    Male            Free
# 3          C00888         Germany   33  Female            Free
# 4          C01674       Australia   18  Female            Free
# ...           ...             ...  ...     ...             ...
# 24995      C07416   United States   32  Female          Silver
# 24996      C04387         Germany   41    Male            Free
# 24997      C07566   United States   32    Male        Platinum
# 24998      C04986  United Kingdom   34  Female            Free
# 24999      C06995     Netherlands   30  Female          Silver
#
#       registration_date  total_orders  total_spend_usd  avg_order_value_usd  \
# 0            2025-10-07            15          1351.52                89.71
# ...

# %%
pd.merge(df1,df2, on="customer_id", how="outer")
# Out:
#       customer_id        country  age  gender membership_tier  \
# 0          C00001  United States   40    Male            Free
# 1          C00001  United States   40    Male            Free
# 2          C00002  United States   20  Female            Free
# 3          C00002  United States   20  Female            Free
# 4          C00002  United States   20  Female            Free
# ...           ...            ...  ...     ...             ...
# 25332      C07998          India   34    Male        Platinum
# 25333      C07999          Japan   44  Female            Free
# 25334      C07999          Japan   44  Female            Free
# 25335      C07999          Japan   44  Female            Free
# 25336      C08000         Poland   37  Female            Gold
#
#       registration_date  total_orders  total_spend_usd  avg_order_value_usd  \
# 0            2019-01-17             4           286.63                63.78
# ...

# %%
pd.concat([df1,df2],axis=0)
# row-wise concatination
# Out:
#       customer_id        country   age  gender membership_tier  \
# 0          C00001  United States  40.0    Male            Free
# 1          C00002  United States  20.0  Female            Free
# 2          C00003  United States  43.0  Female            Gold
# 3          C00004  United States  41.0    Male            Free
# 4          C00005         France  37.0   Other        Platinum
# ...           ...            ...   ...     ...             ...
# 24995      C07416            NaN   NaN     NaN             NaN
# 24996      C04387            NaN   NaN     NaN             NaN
# 24997      C07566            NaN   NaN     NaN             NaN
# 24998      C04986            NaN   NaN     NaN             NaN
# 24999      C06995            NaN   NaN     NaN             NaN
#
#       registration_date  total_orders  total_spend_usd  avg_order_value_usd  \
# 0            2019-01-17           4.0           286.63                63.78
# ...

# %%
pd.concat([df1,df2],ignore_index=True)
# Out:
#       customer_id        country   age  gender membership_tier  \
# 0          C00001  United States  40.0    Male            Free
# 1          C00002  United States  20.0  Female            Free
# 2          C00003  United States  43.0  Female            Gold
# 3          C00004  United States  41.0    Male            Free
# 4          C00005         France  37.0   Other        Platinum
# ...           ...            ...   ...     ...             ...
# 32995      C07416            NaN   NaN     NaN             NaN
# 32996      C04387            NaN   NaN     NaN             NaN
# 32997      C07566            NaN   NaN     NaN             NaN
# 32998      C04986            NaN   NaN     NaN             NaN
# 32999      C06995            NaN   NaN     NaN             NaN
#
#       registration_date  total_orders  total_spend_usd  avg_order_value_usd  \
# 0            2019-01-17           4.0           286.63                63.78
# ...

# %%
pd.concat([df1,df2],axis=1)
# Out:
#       customer_id        country   age  gender membership_tier  \
# 0          C00001  United States  40.0    Male            Free
# 1          C00002  United States  20.0  Female            Free
# 2          C00003  United States  43.0  Female            Gold
# 3          C00004  United States  41.0    Male            Free
# 4          C00005         France  37.0   Other        Platinum
# ...           ...            ...   ...     ...             ...
# 24995         NaN            NaN   NaN     NaN             NaN
# 24996         NaN            NaN   NaN     NaN             NaN
# 24997         NaN            NaN   NaN     NaN             NaN
# 24998         NaN            NaN   NaN     NaN             NaN
# 24999         NaN            NaN   NaN     NaN             NaN
#
#       registration_date  total_orders  total_spend_usd  avg_order_value_usd  \
# 0            2019-01-17           4.0           286.63                63.78
# ...

# %%
df1.set_index("customer_id").join(df2.set_index("customer_id"))
# Out:
#                    country  age  gender membership_tier registration_date  \
# customer_id
# C00001       United States   40    Male            Free        2019-01-17
# C00001       United States   40    Male            Free        2019-01-17
# C00002       United States   20  Female            Free        2026-03-04
# C00002       United States   20  Female            Free        2026-03-04
# C00002       United States   20  Female            Free        2026-03-04
# ...                    ...  ...     ...             ...               ...
# C07998               India   34    Male        Platinum        2026-02-01
# C07999               Japan   44  Female            Free        2026-01-15
# C07999               Japan   44  Female            Free        2026-01-15
# C07999               Japan   44  Female            Free        2026-01-15
# C08000              Poland   37  Female            Gold        2022-07-17
#
#              total_orders  total_spend_usd  avg_order_value_usd  \
# ...
